# %%
from tqdm import tqdm
import os
import json
import uuid
from tqdm import tqdm
from langchain_chroma import Chroma
from langchain.storage import InMemoryStore
from langchain.schema.document import Document
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain_huggingface import HuggingFaceEmbeddings
from transformers import pipeline

# %%
CHUNKS_FOLDER = "processed_chunks"

# %%
def data_info(folder_path = "processed_chunks"):
    json_files = [f for f in os.listdir(folder_path) if f.endswith(".json")]
    total_text = 0
    total_table = 0
    for json_file in tqdm(json_files, desc="Loading chunks", unit="file"):
        file_path = os.path.join(folder_path, json_file)
        composite_count = 0
        table_count = 0
        with open(file_path, "r", encoding="utf-8") as f:
            print(file_path)
            chunk_data = json.load(f)
            # Convert dictionaries back into unstructured objects
            for chunk in chunk_data:
                
                
                element_type = chunk.get("type")
                if element_type == "Table":
                    table_count+=1
                    total_table += 1
                    # print(chunk)
                elif element_type == "CompositeElement":
                    composite_count+=1
                    total_text += 1
            print("Number of Text Elements in this pdf: ",composite_count , "\nNumber of broad tables: ",table_count)
            print("\n")
    print("Total Text chunks: ", total_text, "\nTotal Tables: ", total_table)

# %%
data_info("processed_chunks")
# Out:
# Loading chunks:  31%|███████▍                | 24/78 [00:00<00:00, 234.43file/s]
# processed_chunks/LIC’s Digi Credit Life - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan-25 years - CIS  New Money Back Plan-25 years .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Credit Life - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Amar - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Anand - Policy Document .pdf.json
# Number of Text Elements in this pdf:  25
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Digi Term - CIS LIC’s Digi Term .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/Accident Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  6
# Number of broad tables:  0
#
#
# processed_chunks/New Tech-Term - CIS  New Tech-Term .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/New Term Assurance Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Term - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
#
#
# processed_chunks/Linked Accidental Death Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Labh Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
#
#
# processed_chunks/Bima Jyoti - CIS  Bima Jyoti .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Digi Credit Life - CIS LIC’s Digi Credit Life .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan- 20 Years - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Labh Plan - CIS  Jeevan Labh Plan .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Accidental Death & Disability Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  9
# Number of broad tables:  0
#
#
# processed_chunks/Bima Jyoti - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Bima Shree - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
#
#
# processed_chunks/New Endowment Plan - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Lakshya - Policy Document .pdf.json
# Number of Text Elements in this pdf:  22
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan-25 years - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Lakshya - CIS  Jeevan Lakshya .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Umang - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  36
# Number of broad tables:  2
#
#
# processed_chunks/LIC’s Bima Shree - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
#
#
# processed_chunks/Single Premium Endowment Plan - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
#
#
# processed_chunks/Bima Ratna - Policy Document .pdf.json
# Number of Text Elements in this pdf:  25
# Number of broad tables:  0
#
#
# processed_chunks/New Endowment Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
#
#
# processed_chunks/Saral Jeevan Bima - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  9
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Digi Term - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  13
# Number of broad tables:  0
#
#
# processed_chunks/New Children's Money Back Plan - CIS  New Children's Money Back Plan .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Azad - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/Premium Waiver Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Utsav - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Utsav - Policy Document .pdf.json
# Number of Text Elements in this pdf:  26
# Number of broad tables:  0
#
#
# processed_chunks/New Endowment Plan - CIS  New Endowment Plan .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Labh Plan - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Azad - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
#
#
# processed_chunks/New Children's Money Back Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  24
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Tarun - Policy Document .pdf.json
# Number of Text Elements in this pdf:  21
# Number of broad tables:  0
#
#
# processed_chunks/Saral Jeevan Bima - CIS  Saral Jeevan Bima .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Amar - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Lakshya - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
#
#
# processed_chunks/Amritbaal - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Digi Credit Life - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  11
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan- 20 Years - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan-25 years - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
# Loading chunks: 100%|████████████████████████| 78/78 [00:00<00:00, 262.23file/s]
# processed_chunks/Jeevan Tarun - CIS  Jeevan Tarun .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Bima Shree - CIS LIC’s Bima Shree .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/New Money Back Plan- 20 Years - CIS  New Money Back Plan-20 years .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Single Premium Endowment Plan - CIS  Single Premium Endowment Plan .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/Bima Ratna - CIS  Bima Ratna .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Term - CIS LIC’s Yuva Term .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Digi Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/New Tech-Term - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Anand - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
#
#
# processed_chunks/Linked Accidental Death Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  6
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Anand - CIS  New Jeevan Anand .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
#
#
# processed_chunks/New Term Assurance Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
#
#
# processed_chunks/Saral Jeevan Bima - Policy Document .pdf.json
# Number of Text Elements in this pdf:  15
# Number of broad tables:  0
#
#
# processed_chunks/Amritbaal - CIS  Amritbaal .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Bima Ratna - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
#
#
# processed_chunks/Accidental Death & Disability Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  8
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Credit Life - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  10
# Number of broad tables:  0
#
#
# processed_chunks/New Children's Money Back Plan - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Tarun - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
#
#
# processed_chunks/New Jeevan Amar - CIS  New Jeevan Amar .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/Bima Jyoti - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Azad - CIS  Jeevan Azad .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Umang - Policy Document .pdf.json
# Number of Text Elements in this pdf:  30
# Number of broad tables:  0
#
#
# processed_chunks/Premium Waiver Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/Single Premium Endowment Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
#
#
# processed_chunks/New Tech-Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Umang - CIS  Jeevan Umang .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
#
#
# processed_chunks/LIC’s Yuva Credit Life - CIS LIC’s Yuva Credit Life .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# processed_chunks/Amritbaal - Policy Document .pdf.json
# Number of Text Elements in this pdf:  24
# Number of broad tables:  0
#
#
# processed_chunks/Jeevan Utsav - CIS  Jeevan Utsav .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
#
#
# Total Text chunks:  1024
# Total Tables:  2

# %%
def prepare_lists(folder_path = "processed_chunks"):
    json_files = [f for f in os.listdir(folder_path) if f.endswith(".json")]
    tables = []
    texts = []
    orig_tables = 0
    total_text = 0
    total_table = 0
    for json_file in tqdm(json_files, desc="Loading chunks", unit="file"):
        file_path = os.path.join(folder_path, json_file)
        composite_count = 0
        table_count = 0
        with open(file_path, "r", encoding="utf-8") as f:
            print(file_path)
            chunks = json.load(f)
            # Convert dictionaries back into unstructured objects
            for chunk in chunks:
                element_type = chunk.get("type")
                if element_type == "Table":
                    table_count+=1
                    total_table += 1
                    # print(chunk)
                elif element_type == "CompositeElement":
                    composite_count+=1
                    total_text += 1
                    texts.append(chunk["text"])
                for element in chunk["metadata"]["orig_elements"]:
                    if "text_as_html" in element["metadata"] and element["type"] == "Table":
                        tables.append(element["metadata"]["text_as_html"])
                        orig_tables += 1
                        
            print("Number of Text Elements in this pdf: ",composite_count , "\nNumber of broad tables: ",table_count)
            print("Number of original tables: ", orig_tables)
            print("\n")
    print("Total Text chunks: ", total_text, "\nTotal Tables: ", total_table)
    return tables , texts

# %%
tables , texts = prepare_lists("processed_chunks")
# Out:
# Loading chunks:   0%|                                  | 0/78 [00:00<?, ?file/s]
# processed_chunks/LIC’s Digi Credit Life - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  2
#
#
# processed_chunks/New Money Back Plan-25 years - CIS  New Money Back Plan-25 years .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  4
#
#
# processed_chunks/LIC’s Yuva Credit Life - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  8
#
#
# processed_chunks/New Jeevan Amar - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  11
#
#
# processed_chunks/New Jeevan Anand - Policy Document .pdf.json
# Number of Text Elements in this pdf:  25
# Number of broad tables:  0
# Number of original tables:  19
#
#
# processed_chunks/LIC’s Digi Term - CIS LIC’s Digi Term .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  21
#
#
# processed_chunks/Accident Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  6
# Number of broad tables:  0
# Number of original tables:  22
#
#
# processed_chunks/New Tech-Term - CIS  New Tech-Term .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  24
#
#
# processed_chunks/New Term Assurance Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
# Number of original tables:  25
#
#
# processed_chunks/LIC’s Yuva Term - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
# Number of original tables:  37
#
#
# processed_chunks/Linked Accidental Death Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
# Number of original tables:  37
#
#
# processed_chunks/Jeevan Labh Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
# Number of original tables:  44
#
#
# processed_chunks/Bima Jyoti - CIS  Bima Jyoti .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  46
#
#
# processed_chunks/LIC’s Digi Credit Life - CIS LIC’s Digi Credit Life .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  48
#
#
# processed_chunks/New Money Back Plan- 20 Years - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
# Number of original tables:  53
#
#
# processed_chunks/Jeevan Labh Plan - CIS  Jeevan Labh Plan .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  55
#
#
# processed_chunks/Accidental Death & Disability Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  9
# Number of broad tables:  0
# Number of original tables:  56
#
#
# processed_chunks/Bima Jyoti - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
# Number of original tables:  62
#
#
# processed_chunks/LIC’s Bima Shree - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
# Number of original tables:  71
#
#
# processed_chunks/New Endowment Plan - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
# Number of original tables:  87
#
#
# processed_chunks/Jeevan Lakshya - Policy Document .pdf.json
# Number of Text Elements in this pdf:  22
# Number of broad tables:  0
# Number of original tables:  91
#
#
# processed_chunks/New Money Back Plan-25 years - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
# Number of original tables:  105
#
#
# processed_chunks/Jeevan Lakshya - CIS  Jeevan Lakshya .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  106
#
#
# processed_chunks/Jeevan Umang - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  36
# Number of broad tables:  2
# Number of original tables:  118
#
#
# processed_chunks/LIC’s Bima Shree - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
# Number of original tables:  126
#
#
# processed_chunks/Single Premium Endowment Plan - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
# Number of original tables:  139
#
#
# processed_chunks/Bima Ratna - Policy Document .pdf.json
# Number of Text Elements in this pdf:  25
# Number of broad tables:  0
# Number of original tables:  148
#
#
# processed_chunks/New Endowment Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
# Number of original tables:  154
# Loading chunks:  78%|██████████████████▊     | 61/78 [00:00<00:00, 307.40file/s]
# processed_chunks/Saral Jeevan Bima - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  9
# Number of broad tables:  0
# Number of original tables:  160
#
#
# processed_chunks/LIC’s Digi Term - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  13
# Number of broad tables:  0
# Number of original tables:  171
#
#
# processed_chunks/New Children's Money Back Plan - CIS  New Children's Money Back Plan .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  173
#
#
# processed_chunks/Jeevan Azad - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  185
#
#
# processed_chunks/Premium Waiver Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
# Number of original tables:  186
#
#
# processed_chunks/Jeevan Utsav - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
# Number of original tables:  202
#
#
# processed_chunks/Jeevan Utsav - Policy Document .pdf.json
# Number of Text Elements in this pdf:  26
# Number of broad tables:  0
# Number of original tables:  211
#
#
# processed_chunks/New Endowment Plan - CIS  New Endowment Plan .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  212
#
#
# processed_chunks/Jeevan Labh Plan - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  226
#
#
# processed_chunks/Jeevan Azad - Policy Document .pdf.json
# Number of Text Elements in this pdf:  23
# Number of broad tables:  0
# Number of original tables:  231
#
#
# processed_chunks/New Children's Money Back Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  24
# Number of broad tables:  0
# Number of original tables:  237
#
#
# processed_chunks/Jeevan Tarun - Policy Document .pdf.json
# Number of Text Elements in this pdf:  21
# Number of broad tables:  0
# Number of original tables:  244
#
#
# processed_chunks/Saral Jeevan Bima - CIS  Saral Jeevan Bima .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  246
#
#
# processed_chunks/New Jeevan Amar - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
# Number of original tables:  255
#
#
# processed_chunks/Jeevan Lakshya - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
# Number of original tables:  267
#
#
# processed_chunks/Amritbaal - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  283
#
#
# processed_chunks/LIC’s Digi Credit Life - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  11
# Number of broad tables:  0
# Number of original tables:  290
#
#
# processed_chunks/New Money Back Plan- 20 Years - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  300
#
#
# processed_chunks/New Money Back Plan-25 years - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
# Number of original tables:  307
#
#
# processed_chunks/Jeevan Tarun - CIS  Jeevan Tarun .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  309
#
#
# processed_chunks/LIC’s Bima Shree - CIS LIC’s Bima Shree .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  312
#
#
# processed_chunks/New Money Back Plan- 20 Years - CIS  New Money Back Plan-20 years .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  313
#
#
# processed_chunks/Single Premium Endowment Plan - CIS  Single Premium Endowment Plan .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  315
#
#
# processed_chunks/Bima Ratna - CIS  Bima Ratna .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  317
#
#
# processed_chunks/LIC’s Yuva Term - CIS LIC’s Yuva Term .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  319
#
#
# processed_chunks/LIC’s Digi Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  321
#
#
# processed_chunks/New Tech-Term - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  12
# Number of broad tables:  0
# Number of original tables:  333
#
#
# processed_chunks/New Jeevan Anand - Sales brochure .pdf.json
# Number of Text Elements in this pdf:  16
# Number of broad tables:  0
# Number of original tables:  346
#
#
# processed_chunks/Linked Accidental Death Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  6
# Number of broad tables:  0
# Number of original tables:  347
#
#
# processed_chunks/New Jeevan Anand - CIS  New Jeevan Anand .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  349
#
#
# processed_chunks/LIC’s Yuva Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  20
# Number of broad tables:  0
# Number of original tables:  352
#
#
# processed_chunks/New Term Assurance Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  7
# Number of broad tables:  0
# Number of original tables:  356
#
#
# processed_chunks/Saral Jeevan Bima - Policy Document .pdf.json
# Number of Text Elements in this pdf:  15
# Number of broad tables:  0
# Number of original tables:  359
# Loading chunks: 100%|████████████████████████| 78/78 [00:00<00:00, 315.81file/s]
# processed_chunks/Amritbaal - CIS  Amritbaal .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  361
#
#
# processed_chunks/Bima Ratna - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
# Number of original tables:  377
#
#
# processed_chunks/Accidental Death & Disability Benefit Rider - Policy Document .pdf.json
# Number of Text Elements in this pdf:  8
# Number of broad tables:  0
# Number of original tables:  378
#
#
# processed_chunks/LIC’s Yuva Credit Life - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  10
# Number of broad tables:  0
# Number of original tables:  385
#
#
# processed_chunks/New Children's Money Back Plan - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
# Number of original tables:  396
#
#
# processed_chunks/Jeevan Tarun - Sales Brochure .pdf.json
# Number of Text Elements in this pdf:  18
# Number of broad tables:  0
# Number of original tables:  408
#
#
# processed_chunks/New Jeevan Amar - CIS  New Jeevan Amar .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  410
#
#
# processed_chunks/Bima Jyoti - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  17
# Number of broad tables:  0
# Number of original tables:  427
#
#
# processed_chunks/Jeevan Azad - CIS  Jeevan Azad .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  429
#
#
# processed_chunks/Jeevan Umang - Policy Document .pdf.json
# Number of Text Elements in this pdf:  30
# Number of broad tables:  0
# Number of original tables:  434
#
#
# processed_chunks/Premium Waiver Benefit Rider - Sales Brochures .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  436
#
#
# processed_chunks/Single Premium Endowment Plan - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
# Number of original tables:  443
#
#
# processed_chunks/New Tech-Term - Policy Document .pdf.json
# Number of Text Elements in this pdf:  19
# Number of broad tables:  0
# Number of original tables:  444
#
#
# processed_chunks/Jeevan Umang - CIS  Jeevan Umang .pdf.json
# Number of Text Elements in this pdf:  5
# Number of broad tables:  0
# Number of original tables:  446
#
#
# processed_chunks/LIC’s Yuva Credit Life - CIS LIC’s Yuva Credit Life .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  449
#
#
# processed_chunks/Amritbaal - Policy Document .pdf.json
# Number of Text Elements in this pdf:  24
# Number of broad tables:  0
# Number of original tables:  453
#
#
# processed_chunks/Jeevan Utsav - CIS  Jeevan Utsav .pdf.json
# Number of Text Elements in this pdf:  4
# Number of broad tables:  0
# Number of original tables:  455
#
#
# Total Text chunks:  1024
# Total Tables:  2

# %%
# Initialize the summarization model (BART-large-cnn)
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# Device set to use mps:0

# %%
embedding_function = HuggingFaceEmbeddings(model_name="sentence-transformers/msmarco-roberta-base-v3")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# The vectorstore to use to index the child chunks
vectorstore = Chroma(collection_name="multi_modal_rag", embedding_function=embedding_function)

# The storage layer for the parent documents
store = InMemoryStore()
id_key = "doc_id"

# The retriever (empty to start)
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)

# %%
# Function to summarize texts
def summarize_texts(text_chunks):
    return [summarizer(text, max_length=200, min_length=50, do_sample=False)[0]['summary_text'] for text in text_chunks]

# %%
# Generate summaries
text_summaries = summarize_texts(texts)
table_summaries = summarize_texts(tables)

# Add texts
doc_ids = [str(uuid.uuid4()) for _ in texts]
summary_texts = [
    Document(page_content=summary, metadata={id_key: doc_ids[i]}) for i, summary in enumerate(text_summaries)
]
retriever.vectorstore.add_documents(summary_texts)
retriever.docstore.mset(list(zip(doc_ids, texts)))

# Add tables
table_ids = [str(uuid.uuid4()) for _ in tables]
summary_tables = [
    Document(page_content=summary, metadata={id_key: table_ids[i]}) for i, summary in enumerate(table_summaries)
]
retriever.vectorstore.add_documents(summary_tables)
retriever.docstore.mset(list(zip(table_ids, tables)))

# Persist the database
vectorstore.persist()
# Out:
# Your max_length is set to 200, but your input_length is only 24. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 200, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Generate summaries
# ----> 2 text_summaries = summarize_texts(texts)
#       3 table_summaries = summarize_texts(tables)
#       5 # Add texts
#
# Cell In[18], line 3, in summarize_texts(text_chunks)
#       2 def summarize_texts(text_chunks):
# ----> 3     return [summarizer(text, max_length=200, min_length=50, do_sample=False)[0]['summary_text'] for text in text_chunks]
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:280, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     256 def __call__(self, *args, **kwargs):
#     257     r"""
#     258     Summarize the text(s) given as inputs.
#     259
#    (...)
#     278           ids of the summary.
#     279     """
# --> 280     return super().__call__(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:173, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     144 def __call__(self, *args, **kwargs):
#     145     r"""
#     146     Generate the output text(s) using text(s) given as inputs.
#     147
#    (...)
#     170           ids of the generated text.
#     171     """
# --> 173     result = super().__call__(*args, **kwargs)
#     174     if (
#     175         isinstance(args[0], list)
#     176         and all(isinstance(el, str) for el in args[0])
#     177         and all(len(res) == 1 for res in result)
#     178     ):
#     179         return [res[0] for res in result]
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1362, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1354     return next(
#    1355         iter(
#    1356             self.get_iterator(
#    (...)
#    1359         )
#    1360     )
#    1361 else:
# -> 1362     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1369, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1367 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1368     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1369     model_outputs = self.forward(model_inputs, **forward_params)
#    1370     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1371     return outputs
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1269, in Pipeline.forward(self, model_inputs, **forward_params)
#    1267     with inference_context():
#    1268         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1269         model_outputs = self._forward(model_inputs, **forward_params)
#    1270         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1271 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:202, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     199 if "generation_config" not in generate_kwargs:
#     200     generate_kwargs["generation_config"] = self.generation_config
# --> 202 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     203 out_b = output_ids.shape[0]
#     204 if self.framework == "pt":
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/generation/utils.py:2286, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2278     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2279         input_ids=input_ids,
#    2280         expand_size=generation_config.num_beams,
#    2281         is_encoder_decoder=self.config.is_encoder_decoder,
#    2282         **model_kwargs,
#    2283     )
#    2285     # 13. run beam sample
# -> 2286     result = self._beam_search(
#    2287         input_ids,
#    2288         beam_scorer,
#    2289         logits_processor=prepared_logits_processor,
#    2290         stopping_criteria=prepared_stopping_criteria,
#    2291         generation_config=generation_config,
#    2292         synced_gpus=synced_gpus,
#    2293         **model_kwargs,
#    2294     )
#    2296 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2297     # 11. prepare beam search scorer
#    2298     beam_scorer = BeamSearchScorer(
#    2299         batch_size=batch_size,
#    2300         num_beams=generation_config.num_beams,
#    (...)
#    2306         max_length=generation_config.max_length,
#    2307     )
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/generation/utils.py:3506, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3503     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3505 else:  # Unchanged original behavior
# -> 3506     outputs = self(**model_inputs, return_dict=True)
#    3508 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3509 model_kwargs = self._update_model_kwargs_for_generation(
#    3510     outputs,
#    3511     model_kwargs,
#    3512     is_encoder_decoder=self.config.is_encoder_decoder,
#    3513 )
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/models/bart/modeling_bart.py:1641, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1636     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1637         decoder_input_ids = shift_tokens_right(
#    1638             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1639         )
# -> 1641 outputs = self.model(
#    1642     input_ids,
#    1643     attention_mask=attention_mask,
#    1644     decoder_input_ids=decoder_input_ids,
#    1645     encoder_outputs=encoder_outputs,
#    1646     decoder_attention_mask=decoder_attention_mask,
#    1647     head_mask=head_mask,
#    1648     decoder_head_mask=decoder_head_mask,
#    1649     cross_attn_head_mask=cross_attn_head_mask,
#    1650     past_key_values=past_key_values,
#    1651     inputs_embeds=inputs_embeds,
#    1652     decoder_inputs_embeds=decoder_inputs_embeds,
#    1653     use_cache=use_cache,
#    1654     output_attentions=output_attentions,
#    1655     output_hidden_states=output_hidden_states,
#    1656     return_dict=return_dict,
#    1657 )
#    1659 lm_logits = self.lm_head(outputs[0])
#    1660 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/models/bart/modeling_bart.py:1527, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1520     encoder_outputs = BaseModelOutput(
#    1521         last_hidden_state=encoder_outputs[0],
#    1522         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1523         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1524     )
#    1526 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1527 decoder_outputs = self.decoder(
#    1528     input_ids=decoder_input_ids,
#    1529     attention_mask=decoder_attention_mask,
#    1530     encoder_hidden_states=encoder_outputs[0],
#    1531     encoder_attention_mask=attention_mask,
#    1532     head_mask=decoder_head_mask,
#    1533     cross_attn_head_mask=cross_attn_head_mask,
#    1534     past_key_values=past_key_values,
#    1535     inputs_embeds=decoder_inputs_embeds,
#    1536     use_cache=use_cache,
#    1537     output_attentions=output_attentions,
#    1538     output_hidden_states=output_hidden_states,
#    1539     return_dict=return_dict,
#    1540 )
#    1542 if not return_dict:
#    1543     return decoder_outputs + encoder_outputs
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/models/bart/modeling_bart.py:1379, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1366     layer_outputs = self._gradient_checkpointing_func(
#    1367         decoder_layer.__call__,
#    1368         hidden_states,
#    (...)
#    1376         use_cache,
#    1377     )
#    1378 else:
# -> 1379     layer_outputs = decoder_layer(
#    1380         hidden_states,
#    1381         attention_mask=attention_mask,
#    1382         encoder_hidden_states=encoder_hidden_states,
#    1383         encoder_attention_mask=encoder_attention_mask,
#    1384         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1385         cross_attn_layer_head_mask=(
#    1386             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1387         ),
#    1388         past_key_value=past_key_value,
#    1389         output_attentions=output_attentions,
#    1390         use_cache=use_cache,
#    1391     )
#    1392 hidden_states = layer_outputs[0]
#    1394 if use_cache:
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/models/bart/modeling_bart.py:665, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     663 self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     664 # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 665 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     666     hidden_states=hidden_states,
#     667     past_key_value=self_attn_past_key_value,
#     668     attention_mask=attention_mask,
#     669     layer_head_mask=layer_head_mask,
#     670     output_attentions=output_attentions,
#     671 )
#     672 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     673 hidden_states = residual + hidden_states
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/models/bart/modeling_bart.py:469, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     466 elif past_key_value is not None:
#     467     # reuse k, v, self_attention
#     468     key_states = self._shape(self.k_proj(hidden_states), -1, bsz)
# --> 469     value_states = self._shape(self.v_proj(hidden_states), -1, bsz)
#     470     key_states = torch.cat([past_key_value[0], key_states], dim=2)
#     471     value_states = torch.cat([past_key_value[1], value_states], dim=2)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
def dynamic_summarize(text, prompt_template):
    """Adjust max_length dynamically and prepend a custom prompt for better summarization."""
    input_length = len(text.split())  # Count words
    max_len = min(150, max(30, int(input_length * 0.7)))  
    min_len = min(50, max(10, int(input_length * 0.3)))  
    
    # Prepend the custom prompt
    full_prompt = f"{prompt_template}\n{text}"
    
    return summarizer(full_prompt, max_length=max_len, min_length=min_len, do_sample=False)[0]['summary_text']

# %%
def dynamic_summarize(text, prompt_template, target_length=500):
    """Adjust max_length dynamically and prepend a custom prompt for better summarization.
       Allows for a target summary length, dynamically adjusts if input is shorter.
    """
    input_length = len(text.split())  # Count words

    # Adaptive max_len, but capped at target_length
    max_len = min(target_length, max(30, int(input_length * 0.7)))
    min_len = min(50, max(10, int(input_length * 0.3)))

    # Prepend the custom prompt
    full_prompt = f"{prompt_template}\n{text}"

    try:  # Wrap in a try-except to catch potential summarization errors
        summary = summarizer(full_prompt, max_length=max_len, min_length=min_len, do_sample=False)[0]['summary_text']
        print(summary,"\n\n\n")
        return summary
    except Exception as e:
        print(f"Error during summarization: {e}")  # Handle or log the error
        return "Error generating summary." # Or return a default summary, or raise the exception if you want to stop execution

# %%
for t in texts :
    print(len(t))
# Out:
# 2990
# 3324
# 7120
# 4406
# 3091
# 2930
# 2071
# 2008
# 2252
# 2175
# 3319
# 2469
# 2583
# 4883
# 5454
# 5625
# 54
# 3465
# 2645
# 2068
# 2364
# 337
# 3367
# 3144
# 7016
# 4500
# 3088
# 2930
# 2068
# 2012
# 2249
# 2230
# 3262
# 2467
# 2630
# 4883
# 5454
# 5625
# 54
# 2538
# 4876
# 6535
# 4844
# 2193
# 2637
# 2267
# 3888
# 3562
# 3478
# 2153
# 2192
# 2480
# 2685
# 5711
# 5745
# 4366
# 2682
# 3059
# 2002
# 2833
# 3891
# 6040
# 2674
# 2077
# 2456
# 2020
# 5530
# 2025
# 2599
# 2350
# 3304
# 3907
# 2653
# 2147
# 2500
# 5866
# 5722
# 4357
# 4000
# 6103
# 58
# 3074
# 3141
# 2753
# 817
# 3495
# 3581
# 2947
# 2101
# 2264
# 943
# 3026
# 3169
# 2497
# 1170
# 2251
# 2671
# 2030
# 2663
# 2789
# 2044
# 867
# 2436
# 2105
# 2047
# 2183
# 2114
# 4720
# 2302
# 2038
# 2239
# 4646
# 2088
# 216
# 2593
# 2129
# 2152
# 2520
# 5379
# 2113
# 152
# 2579
# 3046
# 7905
# 6885
# 2362
# 2354
# 2412
# 2398
# 2071
# 6260
# 3519
# 3819
# 3710
# 2384
# 3278
# 2312
# 7647
# 5700
# 4320
# 1373
# 2919
# 2122
# 2009
# 2119
# 1461
# 3048
# 2005
# 2255
# 2036
# 284
# 2639
# 4348
# 6716
# 6015
# 4699
# 2032
# 2395
# 2019
# 6291
# 4176
# 3837
# 2194
# 4555
# 2156
# 2083
# 2760
# 6024
# 5413
# 4672
# 10
# 2902
# 2040
# 2561
# 2155
# 237
# 2883
# 4013
# 2641
# 2148
# 2179
# 2057
# 4418
# 2122
# 153
# 2597
# 3038
# 8011
# 6482
# 4486
# 2316
# 2397
# 2068
# 5331
# 4668
# 3821
# 2247
# 4030
# 3692
# 2153
# 2624
# 5679
# 5699
# 4332
# 1908
# 2024
# 2514
# 2231
# 2122
# 2143
# 5203
# 2373
# 3431
# 3222
# 2110
# 2194
# 2206
# 2219
# 6896
# 2107
# 4472
# 2094
# 221
# 2103
# 2555
# 2504
# 2157
# 2185
# 3728
# 3235
# 5515
# 6084
# 2113
# 2617
# 2649
# 6008
# 2061
# 5458
# 1184
# 3317
# 3092
# 2028
# 6053
# 6289
# 3533
# 2018
# 2186
# 2085
# 6859
# 4299
# 3929
# 2081
# 4512
# 2098
# 2094
# 2672
# 5692
# 5716
# 4353
# 3445
# 52
# 2018
# 3015
# 2147
# 3069
# 2461
# 2123
# 2404
# 2202
# 2930
# 2203
# 2153
# 9497
# 2256
# 4727
# 2037
# 237
# 3208
# 2134
# 2627
# 2638
# 426
# 2114
# 3049
# 3021
# 4190
# 3003
# 2116
# 2615
# 2232
# 9579
# 2226
# 5855
# 764
# 2626
# 436
# 9999
# 1433
# 2001
# 6043
# 2002
# 8551
# 7571
# 2662
# 26
# 9999
# 1595
# 2755
# 7156
# 3914
# 2506
# 3026
# 3619
# 5766
# 2050
# 4417
# 2123
# 154
# 2492
# 3099
# 2230
# 2848
# 6055
# 4272
# 6181
# 2781
# 2118
# 2085
# 3162
# 6270
# 3509
# 6142
# 4663
# 2107
# 2159
# 2615
# 5702
# 5726
# 4364
# 2200
# 64
# 2108
# 2511
# 3445
# 3681
# 5940
# 2421
# 3186
# 2077
# 2913
# 5383
# 2119
# 154
# 2609
# 3040
# 2012
# 6062
# 2636
# 4478
# 2144
# 4167
# 3605
# 5293
# 2730
# 2222
# 2206
# 2766
# 3550
# 2453
# 3624
# 2079
# 2102
# 2090
# 2725
# 5680
# 5701
# 4333
# 1370
# 2678
# 3054
# 5392
# 6002
# 4263
# 3652
# 2419
# 2395
# 2065
# 6216
# 3588
# 2160
# 3857
# 3901
# 2696
# 2100
# 2660
# 5699
# 5720
# 4359
# 6962
# 5451
# 13
# 2716
# 2053
# 4117
# 2311
# 2015
# 2233
# 4178
# 2045
# 880
# 2421
# 2044
# 2047
# 2181
# 2100
# 2031
# 2672
# 2306
# 2025
# 2249
# 4646
# 2088
# 216
# 3355
# 2269
# 2022
# 3147
# 534
# 2009
# 2950
# 4222
# 2231
# 3753
# 2017
# 3527
# 2022
# 2323
# 2181
# 2165
# 3884
# 2453
# 3256
# 2364
# 2076
# 208
# 2239
# 2520
# 2014
# 2226
# 2062
# 2053
# 480
# 3455
# 3495
# 2661
# 3122
# 2219
# 3830
# 2707
# 2087
# 2855
# 2777
# 2236
# 2055
# 3646
# 4096
# 2553
# 5383
# 2121
# 153
# 2459
# 3166
# 2046
# 4085
# 4480
# 3713
# 3093
# 3159
# 2270
# 2461
# 2019
# 2091
# 3663
# 2519
# 2409
# 2909
# 2591
# 2279
# 2660
# 2327
# 2573
# 2550
# 4322
# 5569
# 5606
# 1765
# 2984
# 2011
# 3329
# 1803
# 2024
# 2218
# 2811
# 2719
# 2195
# 4466
# 4570
# 3017
# 2132
# 2182
# 2634
# 3060
# 4598
# 2459
# 4592
# 2124
# 154
# 2573
# 3068
# 2007
# 4145
# 4409
# 4630
# 3081
# 2356
# 2448
# 2021
# 3228
# 3351
# 2773
# 2462
# 3542
# 3716
# 3560
# 2552
# 2540
# 4318
# 5457
# 5502
# 1738
# 2261
# 3409
# 8134
# 6082
# 3558
# 2742
# 2662
# 2256
# 6401
# 4380
# 2626
# 3057
# 2260
# 4709
# 2099
# 2170
# 2691
# 4798
# 4592
# 2048
# 2520
# 4074
# 2081
# 68
# 2573
# 3044
# 8146
# 6884
# 4204
# 2976
# 2021
# 2508
# 4927
# 5552
# 3948
# 2246
# 4623
# 2098
# 2091
# 2708
# 5692
# 5714
# 4345
# 3803
# 13
# 2555
# 2010
# 2011
# 2118
# 1447
# 2400
# 2523
# 2337
# 2038
# 2028
# 3491
# 2402
# 2344
# 2050
# 3995
# 2547
# 205
# 2319
# 3023
# 2575
# 2312
# 2158
# 2322
# 2434
# 6271
# 3762
# 3148
# 2611
# 2436
# 2189
# 2927
# 2205
# 5399
# 2118
# 153
# 2566
# 5381
# 7410
# 2610
# 2101
# 3152
# 2649
# 4922
# 4469
# 3033
# 2590
# 2199
# 2131
# 2760
# 4605
# 2113
# 1126
# 2301
# 2525
# 2300
# 2657
# 2020
# 2113
# 2295
# 2017
# 4431
# 2116
# 154
# 2097
# 2680
# 2126
# 3070
# 3788
# 3138
# 2273
# 2533
# 2205
# 2153
# 2608
# 3048
# 2178
# 2054
# 4559
# 2142
# 238
# 2634
# 3141
# 8135
# 3938
# 3724
# 2477
# 2459
# 2395
# 2018
# 6290
# 4182
# 3834
# 2194
# 3929
# 2776
# 2082
# 6900
# 7299
# 5673
# 3254
# 2107
# 2021
# 2961
# 873
# 2728
# 3600
# 2694
# 2100
# 3170
# 2304
# 2860
# 2074
# 477
# 3192
# 3067
# 2149
# 378
# 2638
# 3364
# 2935
# 2020
# 378
# 2891
# 2011
# 2571
# 2077
# 244
# 7290
# 6598
# 4871
# 2124
# 2007
# 2139
# 3960
# 2058
# 2596
# 2084
# 2235
# 2192
# 2466
# 2488
# 5912
# 5752
# 4459
# 2512
# 2530
# 2703
# 2590
# 2096
# 2123
# 2401
# 2308
# 2085
# 4458
# 2336
# 872
# 2496
# 3448
# 3565
# 3542
# 3179
# 3207
# 2344
# 6108
# 2295
# 2103
# 2628
# 3601
# 2740
# 2067
# 5458
# 1184
# 3479
# 3443
# 2307
# 2360
# 3216
# 875
# 2816
# 2001
# 2714
# 2261
# 237
# 2524
# 3172
# 2168
# 6173
# 4957
# 2040
# 2006
# 2139
# 3961
# 2057
# 2029
# 2758
# 2236
# 2192
# 2468
# 2489
# 5914
# 5753
# 4396
# 63
# 2265
# 2986
# 2433
# 2103
# 4756
# 2124
# 252
# 2559
# 3335
# 7023
# 4260
# 3293
# 2348
# 2938
# 2760
# 2020
# 2375
# 2401
# 7051
# 5636
# 4957
# 53
# 2563
# 2009
# 3352
# 2710
# 831
# 3094
# 2113
# 2007
# 2083
# 4104
# 2046
# 2399
# 3294
# 6152
# 4530
# 2376
# 2189
# 2090
# 2651
# 2777
# 2838
# 2588
# 2088
# 216
# 4619
# 4788
# 3140
# 3101
# 2268
# 2291
# 2409
# 889
# 2358
# 2536
# 2030
# 2823
# 2941
# 2121
# 2296
# 2015
# 4437
# 2048
# 2004
# 2467
# 2551
# 3568
# 2324
# 2190
# 2513
# 2993
# 4292
# 2137
# 2242
# 8198
# 4623
# 2248
# 4658
# 2109
# 2326
# 68
# 2138
# 2204
# 2057
# 2237
# 2314
# 2256
# 2195
# 2584
# 2482
# 5642
# 2190
# 2177
# 8124
# 2838
# 2112
# 4477
# 2099
# 227
# 3028
# 3169
# 2422
# 1245
# 2613
# 2102
# 2668
# 2997
# 3370
# 2256
# 4051
# 4067
# 2053
# 3097
# 2585
# 2048
# 2192
# 2032
# 2022
# 5462
# 1242
# 3009
# 2069
# 2918
# 2140
# 292
# 2562
# 3028
# 2006
# 6200
# 6213
# 3232
# 2623
# 3133
# 2125
# 2085
# 2335
# 4325
# 3291
# 2575
# 2157
# 2293
# 3180
# 2135
# 2088
# 2661
# 5677
# 5701
# 4339
# 7326
# 8618
# 9072
# 62
# 10000
# 2218
# 39
# 2224
# 2276
# 2888
# 6408
# 1245
# 2626
# 2953
# 6407
# 5109
# 3108
# 2324
# 3586
# 3934
# 3642
# 2159
# 3461
# 2307
# 2499
# 2563
# 5871
# 5712
# 4354
# 2087
# 7
# 2455
# 3159
# 2062
# 6155
# 4837
# 2194
# 2639
# 2265
# 3873
# 3515
# 3419
# 2152
# 2193
# 2401
# 2682
# 5710
# 5719
# 4378
# 85
# 2759
# 2256
# 2003
# 2408
# 1362
# 3085
# 2211
# 2136
# 2203
# 2547
# 3068
# 2030
# 5583
# 5229
# 2365
# 2358
# 2820
# 2384
# 2122
# 7599
# 2983
# 3083
# 3998
# 2420
# 2475
# 2879
# 2289
# 2562
# 2671
# 5774
# 5723
# 4366
# 492
# 3062
# 2010
# 2548
# 1143

# %%
prompt_template = """
You are an assistant tasked with summarizing tables and text.
Give a concise summary of the table or text.

Respond only with the summary, no additionnal comment.
Do not start your message by saying "Here is a summary" or anything like that.
Just give the summary as it is.

Table or text chunk: {element}

"""
# Generate summaries with progress bar
print("Summarizing text chunks...")
text_summaries = [dynamic_summarize(text, prompt_template) 
                  for text in tqdm(texts, desc="Summarizing Texts")]

print("Summarizing table chunks...")
table_summaries = [dynamic_summarize(table, prompt_template) 
                   for table in tqdm(tables, desc="Summarizing Tables")]

# Generate document IDs with progress bar
print("Generating document IDs...")
doc_ids = [str(uuid.uuid4()) for _ in tqdm(texts, desc="Generating Text IDs")]
table_ids = [str(uuid.uuid4()) for _ in tqdm(tables, desc="Generating Table IDs")]

# Create summary document objects with progress bar
print("Creating text document objects...")
summary_texts = [Document(page_content=summary, metadata={id_key: doc_ids[i]}) 
                 for i, summary in tqdm(enumerate(text_summaries), desc="Creating Text Docs", total=len(text_summaries))]

print("Creating table document objects...")
summary_tables = [Document(page_content=summary, metadata={id_key: table_ids[i]}) 
                  for i, summary in tqdm(enumerate(table_summaries), desc="Creating Table Docs", total=len(table_summaries))]

# Add texts to vectorstore with progress bar
print("Adding text summaries to vectorstore...")
for doc in tqdm(summary_texts, desc="Storing Texts in Vectorstore"):
    retriever.vectorstore.add_documents([doc])

print("Adding text summaries to docstore...")
for doc_id, text in tqdm(zip(doc_ids, texts), desc="Storing Texts in Docstore", total=len(texts)):
    retriever.docstore.mset([(doc_id, text)])

# Add tables to vectorstore with progress bar
print("Adding table summaries to vectorstore...")
for doc in tqdm(summary_tables, desc="Storing Tables in Vectorstore"):
    retriever.vectorstore.add_documents([doc])

print("Adding table summaries to docstore...")
for table_id, table in tqdm(zip(table_ids, tables), desc="Storing Tables in Docstore", total=len(tables)):
    retriever.docstore.mset([(table_id, table)])

# Persist the database
print("Saving vectorstore...")
vectorstore.persist()
print("✅ Database saved successfully!")
# Out:
# Summarizing text chunks...
# Summarizing Texts:   0%|                     | 1/1024 [00:04<1:16:09,  4.47s/it]
# You are an assistant tasked with summarizing tables and text. Give a concise summary of the table or text.Respond only with the summary, no additionnal comment. Do not start your message by saying "Here is a summary" or anything like that. Just give the summary as it is.
# Summarizing Texts:   0%|                     | 2/1024 [00:08<1:07:56,  3.99s/it]
# You are an assistant tasked with summarizing tables and text. Give a concise summary of the table or text.Respond only with the summary, no additionnal comment. The approved version of Policy Document in respect of this plan is available on our website: www.licindia.in.
# Summarizing Texts:   0%|                     | 3/1024 [00:13<1:18:11,  4.59s/it]
# You are an assistant tasked with summarizing tables and text. Give a concise summary of the table or text.Respond only with the summary, no additionnal comment. Do not start your message by saying "Here is a summary" or anything like that. Give the summary as it is.
# Summarizing Texts:   0%|                     | 4/1024 [00:18<1:22:58,  4.88s/it]
# LIC’s Digi Credit Life (UIN: 512N358V01) Page 6 of 18: Nomination is the process of nominating a person(s) in the proposal form or subsequently included/ changed by an endorsement. Proposer is a person who proposes the life insurance proposal.
# Summarizing Texts:   0%|                     | 4/1024 [00:19<1:21:56,  4.82s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 14
#      12 # Generate summaries with progress bar
#      13 print("Summarizing text chunks...")
# ---> 14 text_summaries = [dynamic_summarize(text, prompt_template)
#      15                   for text in tqdm(texts, desc="Summarizing Texts")]
#      17 print("Summarizing table chunks...")
#      18 table_summaries = [dynamic_summarize(table, prompt_template)
#      19                    for table in tqdm(tables, desc="Summarizing Tables")]
#
# Cell In[33], line 15, in dynamic_summarize(text, prompt_template, target_length)
#      12 full_prompt = f"{prompt_template}\n{text}"
#      14 try:  # Wrap in a try-except to catch potential summarization errors
# ---> 15     summary = summarizer(full_prompt, max_length=max_len, min_length=min_len, do_sample=False)[0]['summary_text']
#      16     print(summary,"\n\n\n")
#      17     return summary
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:280, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     256 def __call__(self, *args, **kwargs):
#     257     r"""
#     258     Summarize the text(s) given as inputs.
#     259
#    (...)
#     278           ids of the summary.
#     279     """
# --> 280     return super().__call__(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:173, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     144 def __call__(self, *args, **kwargs):
#     145     r"""
#     146     Generate the output text(s) using text(s) given as inputs.
#     147
#    (...)
#     170           ids of the generated text.
#     171     """
# --> 173     result = super().__call__(*args, **kwargs)
#     174     if (
#     175         isinstance(args[0], list)
#     176         and all(isinstance(el, str) for el in args[0])
#     177         and all(len(res) == 1 for res in result)
#     178     ):
#     179         return [res[0] for res in result]
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1362, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1354     return next(
#    1355         iter(
#    1356             self.get_iterator(
#    (...)
#    1359         )
#    1360     )
#    1361 else:
# -> 1362     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1369, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1367 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1368     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1369     model_outputs = self.forward(model_inputs, **forward_params)
#    1370     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1371     return outputs
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/base.py:1269, in Pipeline.forward(self, model_inputs, **forward_params)
#    1267     with inference_context():
#    1268         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1269         model_outputs = self._forward(model_inputs, **forward_params)
#    1270         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1271 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/pipelines/text2text_generation.py:202, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     199 if "generation_config" not in generate_kwargs:
#     200     generate_kwargs["generation_config"] = self.generation_config
# --> 202 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     203 out_b = output_ids.shape[0]
#     204 if self.framework == "pt":
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/generation/utils.py:2148, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2137     warnings.warn(
#    2138         "You are calling .generate() with the `input_ids` being on a device type different"
#    2139         f" than your model's device. `input_ids` is on {input_ids.device.type}, whereas the model"
#    (...)
#    2144         UserWarning,
#    2145     )
#    2147 # 9. prepare logits processors and stopping criteria
# -> 2148 prepared_logits_processor = self._get_logits_processor(
#    2149     generation_config=generation_config,
#    2150     input_ids_seq_length=input_ids_length,
#    2151     encoder_input_ids=inputs_tensor,
#    2152     prefix_allowed_tokens_fn=prefix_allowed_tokens_fn,
#    2153     logits_processor=logits_processor,
#    2154     device=inputs_tensor.device,
#    2155     model_kwargs=model_kwargs,
#    2156     negative_prompt_ids=negative_prompt_ids,
#    2157     negative_prompt_attention_mask=negative_prompt_attention_mask,
#    2158 )
#    2159 prepared_stopping_criteria = self._get_stopping_criteria(
#    2160     generation_config=generation_config, stopping_criteria=stopping_criteria, tokenizer=tokenizer, **kwargs
#    2161 )
#    2163 # Set model_kwargs `use_cache` so we can use it later in forward runs
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/generation/utils.py:994, in GenerationMixin._get_logits_processor(self, generation_config, input_ids_seq_length, encoder_input_ids, prefix_allowed_tokens_fn, logits_processor, device, model_kwargs, negative_prompt_ids, negative_prompt_attention_mask)
#     987     processors.append(
#     988         ForcedBOSTokenLogitsProcessor(
#     989             generation_config.forced_bos_token_id,
#     990         )
#     991     )
#     992 if generation_config.forced_eos_token_id is not None:
#     993     processors.append(
# --> 994         ForcedEOSTokenLogitsProcessor(
#     995             generation_config.max_length,
#     996             generation_config.forced_eos_token_id,
#     997             device=device,
#     998         )
#     999     )
#    1000 if generation_config.remove_invalid_values is True:
#    1001     processors.append(InfNanRemoveLogitsProcessor())
#
# File ~/miniforge3/lib/python3.12/site-packages/transformers/generation/logits_process.py:1606, in ForcedEOSTokenLogitsProcessor.__init__(self, max_length, eos_token_id, device)
#    1604     if isinstance(eos_token_id, int):
#    1605         eos_token_id = [eos_token_id]
# -> 1606     eos_token_id = torch.tensor(eos_token_id, device=device)
#    1607 self.eos_token_id = eos_token_id
#    1609 if torch.is_floating_point(eos_token_id) or (eos_token_id < 0).any():
#
# KeyboardInterrupt:

# %%
# Function to load and query the database
def query_database(query_text, top_k=3):
    vectorstore = Chroma(persist_directory="db", collection_name="multi_modal_rag", embedding_function=embedding_function)
    retriever = vectorstore.as_retriever(search_kwargs={"k": top_k})
    results = retriever.get_relevant_documents(query_text)
    return results
