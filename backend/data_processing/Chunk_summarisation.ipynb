# %%
from tqdm import tqdm
import os
import json

# %%
def load_chunks_from_json(output_folder="processed_chunks"):
    """
    Reads all saved chunk JSON files and reconstructs them into unstructured objects.
    
    Args:
        output_folder (str): Path where processed chunks are stored.
    
    Returns:
        list: List of unstructured document elements.
    """
    all_chunks = []
    json_files = [f for f in os.listdir(output_folder) if f.endswith(".json")]
    
    for json_file in tqdm(json_files, desc="Loading chunks", unit="file"):
        file_path = os.path.join(output_folder, json_file)
        with open(file_path, "r", encoding="utf-8") as f:
            chunk_data = json.load(f)
            
            # Convert dictionaries back into unstructured objects
            for chunk in chunk_data:
                element_type = chunk.get("type")
                if element_type == "Table":
                    all_chunks.append(Table.from_dict(chunk))
                elif element_type == "NarrativeText":
                    all_chunks.append(NarrativeText.from_dict(chunk))
                elif element_type == "Title":
                    all_chunks.append(Title.from_dict(chunk))
                elif element_type == "ListItem":
                    all_chunks.append(ListItem.from_dict(chunk))
                elif element_type == "Header":
                    all_chunks.append(Header.from_dict(chunk))
                elif element_type == "Image":
                    all_chunks.append(Image.from_dict(chunk))
                elif element_type == "Text":
                    all_chunks.append(Text.from_dict(chunk))
    
    return all_chunks

# %%
CHUNKS_FOLDER = "processed_chunks"
chunks = load_chunks_from_json(CHUNKS_FOLDER)
# Out:
# Loading chunks:  29%|██████████▌                         | 22/75 [00:00<00:00, 337.27file/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 CHUNKS_FOLDER = "processed_chunks"
# ----> 2 chunks = load_chunks_from_json(CHUNKS_FOLDER)
#
# Cell In[1], line 23, in load_chunks_from_json(output_folder)
#      21 element_type = chunk.get("type")
#      22 if element_type == "Table":
# ---> 23     all_chunks.append(Table.from_dict(chunk))
#      24 elif element_type == "NarrativeText":
#      25     all_chunks.append(NarrativeText.from_dict(chunk))
#
# NameError: name 'Table' is not defined

# %%
all_chunks = []
json_files = [f for f in os.listdir("processed_chunks") if f.endswith(".json")]

for json_file in tqdm(json_files, desc="Loading chunks", unit="file"):
    file_path = os.path.join("processed_chunks", json_file)
    with open(file_path, "r", encoding="utf-8") as f:
        chunk_data = json.load(f)
        count = 0
        # Convert dictionaries back into unstructured objects
        for chunk in chunk_data:
            count += 1
            print(count)
            element_type = chunk.get("type")
            print(element_type)
            # if element_type == "Table":
            #     all_chunks.append(Table.from_dict(chunk))
            # elif element_type == "NarrativeText":
            #     all_chunks.append(NarrativeText.from_dict(chunk))
            # elif element_type == "Title":
            #     all_chunks.append(Title.from_dict(chunk))
            # elif element_type == "ListItem":
            #     all_chunks.append(ListItem.from_dict(chunk))
            # elif element_type == "Header":
            #     all_chunks.append(Header.from_dict(chunk))
            # elif element_type == "Image":
            #     all_chunks.append(Image.from_dict(chunk))
            # elif element_type == "Text":
            #     all_chunks.append(Text.from_dict(chunk))
        print("\n")
# Out:
# Loading chunks: 100%|███████████████████████████████████| 77/77 [00:00<00:00, 1145.70file/s]
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
# 25
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# Table
# 14
# Table
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
# 25
# CompositeElement
# 26
# CompositeElement
# 27
# CompositeElement
# 28
# CompositeElement
# 29
# CompositeElement
# 30
# CompositeElement
# 31
# CompositeElement
# 32
# CompositeElement
# 33
# CompositeElement
# 34
# CompositeElement
# 35
# CompositeElement
# 36
# CompositeElement
# 37
# CompositeElement
# 38
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
# 25
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
# 25
# CompositeElement
# 26
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
# 25
# CompositeElement
# 26
# CompositeElement
# 27
# CompositeElement
# 28
# CompositeElement
# 29
# CompositeElement
# 30
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement
# 5
# CompositeElement
# 6
# CompositeElement
# 7
# CompositeElement
# 8
# CompositeElement
# 9
# CompositeElement
# 10
# CompositeElement
# 11
# CompositeElement
# 12
# CompositeElement
# 13
# CompositeElement
# 14
# CompositeElement
# 15
# CompositeElement
# 16
# CompositeElement
# 17
# CompositeElement
# 18
# CompositeElement
# 19
# CompositeElement
# 20
# CompositeElement
# 21
# CompositeElement
# 22
# CompositeElement
# 23
# CompositeElement
# 24
# CompositeElement
#
#
# 1
# CompositeElement
# 2
# CompositeElement
# 3
# CompositeElement
# 4
# CompositeElement

# %%
type(chunk_data)
# Out:
# list

# %%
chunk_data[0]
# Out:
# {'type': 'CompositeElement',
#  'element_id': '9f457e374e333fe2b15c396a056d5286',
#  'text': 'le IAS saaeetrer ofrerst far\n\nCUSTOMER INFORMATION SHEET /KNOW YOUR POLICY\n\nThis document provides key information about your policy. You are also advised to go through your Policy Document.\n\nSl. Title Description in Simple Words No. (Please refer to applicable Policy Clause Number in next column) 1. Name of the Insurance LIC’s Jeevan Utsav Product and Unique (UIN: 512N363V02) Identification Number (UIN) 2 Policy Number _____________________ 3 Type of Insurance Non-Par, Non-Linked, Individual, Savings, Whole Policy Life Insurance Plan 4 Basic Policy details Instalment Premium (Rs): __________ (Taxes, if any, as applicable from time to time are charged extra). Mode of premium payment: _______ Premium Payment Term: _________ Basic Sum Assured (Rs): __________ Sum Assured on Death: Sum Assured on Death is defined as Higher of Basic Sum Assured or 7 times of Annualized Premium 5 Riders opted, if any <<Not Applicable (if rider is not opted)>> <<Rider Name and UIN (as opted for by the policyholder) For details of Benefits and Conditions of riders(s), mentioned above, refer Endorsement to this policy.>> 6 Policy Coverage / Benefit payable on Death: benefits payable On death of the Life Assured after the date of commencement of risk, Death Benefit equal to “Sum Assured on Death” along with accrued Guaranteed Additions shall be payable, Policy Clause Number Part A Part A Part B - Definitions Schedule Schedule Schedule Schedule Condition 1.A of Part C Schedule Condition 1.A of Part C\n\n1\n\n7 Options available (in case of Linked Insurance Products) provided the policy is in-force. This Death Benefit shall not be less than 105% of total premiums paid upto the date of death. Survival Benefit: Survival Benefits in form of Regular Income Benefit or Flexi Income Benefit as per the option chosen . Guaranteed Additions: Under an inforce policy, the Guaranteed Additions shall accrue at the rate of Rs. 40 per thousand Basic Sum Assured at the end of each policy year during the Premium Paying Term. There shall be no further accrual of Guaranteed Additions after Premium Paying Term. Surrender Benefits: The policy can be surrendered by the policyholder after completion of first policy year provided one full year’s premium(s) has been paid. However, the policy shall acquire Guaranteed Surrender Value on payment of atleast two full years’ premiums and Special Surrender Value after completion of first policy year provided one full year’s premium(s) has been paid. On surrender of an in-force or paid- up policy, the Corporation shall pay the Surrender Value equal to higher of Guaranteed Surrender Value and Special Surrender Value. Options to Policyholders for availing benefits, if any, covered under the policy: i) Option to take Death Benefit in instalments: This is an option to receive Death Benefit in instalments over the chosen period of 5 or 10 or 15 years instead of lump sum amount under an in-force as well as paid-up policy. Not Applicable Condition 1.B of Part C Condition 2 of Part C Condition 4 of Part D Condition 8 of Part D\n\n8',
#  'metadata': {'filetype': 'application/pdf',
#   'languages': ['eng'],
#   'last_modified': '2025-01-28T17:54:46',
#   'page_number': 1,
#   'text_as_html': '<table><thead><tr><th>Sl. No.</th><th>Title</th><th>Description in Simple Words (Please refer to applicable Policy Clause Number in | next column)</th><th>Policy Clause Number</th></tr></thead><tbody><tr><td>1.</td><td>Name of the Insurance Product and Unique Identification © Number (UIN)</td><td>LIC’s Jeevan Utsav (UIN: 512N363V02)</td><td>PartA</td></tr><tr><td>2</td><td>Policy Number</td><td></td><td>PartA</td></tr><tr><td>3</td><td>Type of Insurance Policy</td><td>Non-Par, Non-Linked, Individual, Savings, Whole | Life Insurance Plan</td><td>Part B - Definitions</td></tr><tr><td rowspan="5">4</td><td rowspan="5">Basic Policy details</td><td>e Instalment Premium (Rs): (Taxes, if any, as applicable from time to time are charged extra).</td><td>Schedule</td></tr><tr><td>e Mode of premium payment:</td><td>Schedule</td></tr><tr><td>e¢ Premium Payment Term:</td><td>Schedule</td></tr><tr><td>¢ Basic Sum Assured (Rs):</td><td>Schedule</td></tr><tr><td>e Sum Assured on Death: Sum Assured on | Death is defined as Higher of Basic Sum | Assured or 7 times of Annualized Premium</td><td>Condition 1.A of Part Cc</td></tr><tr><td>5</td><td>Riders opted, if any</td><td></td><td>Schedule</td></tr><tr><td>6</td><td>Policy Coverage / benefits payable</td><td>e Benefit payable on Death: On death of the Life Assured after the date of | commencement of risk, Death Benefit equal to “Sum Assured on Death” along with accrued Guaranteed Additions shall be payable,</td><td>Condition 1.A of Part Cc</td></tr></tbody></table>',
#   'orig_elements': '...',
#   'file_directory': '../../policy_documents',
#   'filename': 'Jeevan Utsav - CIS  Jeevan Utsav .pdf'}}

# %%
import json

def read_json(file_path):
    """
    Reads a JSON file and converts it into a Python dictionary.

    Args:
        file_path (str): Path to the JSON file.

    Returns:
        dict: The data from the JSON file as a Python dictionary.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)  # Convert JSON content to a Python dictionary
    return data

# Example usage:
file_path = 'processed_chunks/Jeevan Azad - CIS  Jeevan Azad .pdf.json'  # Replace with your JSON file path
data_dict = read_json(file_path)

# Print the dictionary to check the content
print(data_dict)
# Out:
# [{'type': 'CompositeElement', 'element_id': '587b5699ae2792cc78210bd68957830a', 'text': 'EILic LIFE INSURANCE CORPORATION OF INDIA\n\nCUSTOMER INFORMATION SHEET / KNOW YOUR POLICY\n\nThis document provides key information about your policy. You are also advised to go through your Policy Document.\n\nSl. Title Description in Simple Words Policy Clause no. (Please refer to applicable Policy Clause Number Number in next column) 1. Name of the LIC’s Jeevan Azad (UIN: 512N348V02) Part A Insurance Product And Unique Identification Number(UIN) 2. Policy Number _____________________ Part A 3. Type of Non-Linked other than Pure risk and pension Part B - Definitions Insurance Policy 4. Basic Policy Instalment Premium (Rs): __________ Schedule details (Taxes, if any, as applicable from time to time are charged extra). Mode of premium payment: _______ Schedule Premium Payment Term: _________ Schedule Policy Term: __________ Schedule Basic Sum Assured (Rs): __________ Sum Assured on Death: Sum Assured on Death is defined as Higher of Basic Sum Assured or 7 times of Annualized Premium Sum Assured on Maturity: Sum Assured on Schedule Condition 1.A of Part C Condition 1.B of Maturity is equal to Basic Sum Assured. Part C (The total Basic Sum Assured under all the policies issued to an individual under this plan Part B- Definitions and under all Policies issued in the earlier version of this plan shall not exceed Rs 5 lakh.) 5. Riders opted, if <<Not Applicable (if rider is not opted)>> Schedule\n\nany\n\n<<Rider Name and UIN (as opted for by the\n\npolicyholder)\n\nFor details of Benefits and Conditions of\n\n1\n\n6. Policy Coverage/ benefits payable riders(s), mentioned above, refer Endorsement to this policy.>> Benefit payable on Death: Death benefit payable on death of the life assured during the policy term after the date of commencement of risk but before the stipulated date of maturity, provided the policy is in-force, shall be “Sum Assured on Death”. This Death Benefit shall not be less than 105% of total premiums paid upto the date of death. However, in case of minor Life Assured, whose age at entry is below 8 years, on death before the commencement of Risk, the Death Benefit payable shall be refundof premium(s) paid (excluding taxes, any extra premium and rider premium(s) if any), without interest Benefit payable on Maturity: On Life Assured surviving the stipulated Date of Maturity provided the policy is in-force, “Sum Assured on Maturity” shall be payable. Surrender Benefit: The policy can be surrendered by the policyholder after completion of first policy year provided one full year’s premium(s) has been paid. However, the policy shall acquire Guaranteed Surrender Value on payment of atleast two full years’ premiums and Special Surrender Value after completion of first policy year provided one full year’s premium(s) has been paid. On surrender of an in-force or paid-up policy, the Corporation shall pay the Surrender Value equal to higher of Guaranteed Surrender Value and Special Surrender Value. Condition 1.A of Part C Condition 1.B of Part C Condition 4 of Part D', 'metadata': {'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-28T17:54:40', 'page_number': 1, 'text_as_html': '<table><thead><tr><th>SI. no.</th><th>Title</th><th>Description in Simple Words (Please refer to applicable Policy Number in next column)</th><th>Clause</th><th>Policy Clause Number</th></tr></thead><tbody><tr><td></td><td>Name of the Insurance Product And Unique Identification Number(UIN)</td><td>LIC’s Jeevan Azad (UIN: 512N348V02)</td><td></td><td>PartA</td></tr><tr><td></td><td>Policy Number</td><td></td><td></td><td>PartA</td></tr><tr><td></td><td>Type of Insurance Policy</td><td>Non-Linked other than Pure risk and</td><td>pension</td><td>Part B - Definitions</td></tr><tr><td rowspan="8"></td><td>Basic Policy details</td><td>e Instalment Premium (Rs): (Taxes, if any, as applicable from time are charged extra).</td><td>time to< ...

# %%
data_dict[0].get("metadata").get("orig_elements")
# Out:
# '...'

# %%
import base64

# Replace with your actual encoded string
encoded_string = "..."
# Decode the string from base64
decoded_data = base64.b64decode(encoded_string)

#

# %%
decoded_data
# Out:
b8\xc5\xad\x9ft\x94gL\xc6\x1f\x98\xfa\xa1XH\x86\xe6\xd1\x16\x06\xbf\xa7uS&\xf5\x83\xb2\xb9\x1b\t\xb3\xf9W4E\xf0U\xbf\xed\x94M\xedO}\xd2\x94\xd7\xcf\x99\xb2\xb3X\x8a \xc4(\x9f\xf0D\x931\xde\xa6\xd9\x04\xa1IP\xac2+\x15\x04\xcb\x12\xcc\xd0\xc2:5\r\xefh\xf7+MU@\x8c\x94\x90U\x05\xd7qZ\xa6\x89\xc2\xbe\x16\xf9\xbe\xc0<\x02\xd5Rhdy\x8dW$\xe28\xf9\xb2\x02\x07R\xfae\xa9\x0f\xa4%\xa6\x88\x15\x06\xb5;^N\x10\xc1&\x1e\xd8k\x99xO%\x96\xd9\xb8\xf4\xb8Ju\x90\xa9\x04\x9eK!\x8f\x19\x1f\xd3\xd06I\xe5Q~\xd8\x90b\xd0G0N\x08\xdb\x12\xbar\xea\xe1\x8f&\x10\xb0\xf4\'\xa9\xeff\xeaO\xb7\x8b\x8d\x18\xb5<\xbe\x05]CK\xd30E\xcfk\x89\x00\x88\x0e\x8f\xa8x#\xf1\x8e\xec\xea\x08\xa1\xe3\xed\xadI\x19\x1d\xb5\x89\x9c72*\xac\xed:\xc9\x9a0a\x ...

# %%
import base64

# Base64 encoded string
encoded_string = "..."

# Decode the base64 string
decoded_bytes = base64.b64decode(encoded_string)

# Convert the decoded bytes to a string (if it's text)
decoded_string = decoded_bytes.decode('utf-8', errors='ignore')

# Print the decoded string
print(decoded_string)
# Out:
# xYOܺWF+]	My!N%
# s[@;ll`m%v=o̸xV$l3FbۍM_}-<adӘs6يהњ߳(Kd!o%On5J,P'^t"OZ}h:nt;jltϪ+qO
# b..Τ=B3Cc fZ%%mu=a^gx~&L8+y4fR欉j8\g?2A3Rѯٹ>=BXT;w4ÿ(1i:avݑKRY0^N&BЫCfM'jqۓחpqoN'F-RsHLC-MKMSeNLe1R[1,56dB4~o!X&<j%W?@yR!Z	E&уhɁU%gPpC,v_pF7aD1w'o8Ҩq)yt>c3=PqY%J'A7Y֫T(4Lz)JթYo1W**BIU*R*عH98Z
# Zևj$~j#`շ^g#N;:\y#ϴwImx/uT_f[B(mAc'Y"`l2
# 'A,e%ˬjڝp.mowe <Y{	&т(64XfyC-|l"Hn{g%uasXOxNƞq(B<]CK0EkxI72*:ɚ0aޘ'@n$ҍ\&,K>'FGS\g,Öl5m|<=%67%^ԜɈ=88ɇCFb!9wիGͫЙ[EEfj3Pj-Bx5#OQn@2/AH([8(/0 v5"DAbx(tCk:f@`J*2+`Wb$AMkKL_#[̉M$v/{W\G7'RqzyY)zhw{G1׬ 4P5?zqMR$̲=6%Jo0GduaުUӬ[X`PZFF8L
# ?ಜo,kB;Q¤D-ΑdHtQs_.BVpz%b9_`6Urh4n/X{uR^UM4
# "]upQUhS eMFp7hwo(#lTDϤFa5:6	ZRM~8 x
# Br*eWQ1<zY` &iMn9"/ճB+<5k3=?讕
